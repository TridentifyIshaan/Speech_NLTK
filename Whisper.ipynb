# %% [markdown]
# # Speech Translation using Whisper Model
#
# This notebook demonstrates how to use OpenAI's Whisper model to translate speech from one language to another. The workflow includes:
#
# 1. Loading and preprocessing audio files
# 2. Using the Whisper model for speech-to-text translation
# 3. Translating audio from the source language to French
#
# The example uses the `openai/whisper-small` model to process an audio file and generate translated text output.

# %%
# %pip install transformers torch librosa sentencepiece pydub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
import numpy as np
import soundfile as sf
from pydub import AudioSegment
import torch
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# %%
model_name = "openai/whisper-small"

# %%
import os, getpass

# %%
os.environ['HF_TOKEN'] = getpass.getpass('Enter HF token: ')

# %%
processor = WhisperProcessor.from_pretrained(model_name)
model = WhisperForConditionalGeneration.from_pretrained(model_name)

# %%
audio_path = "input.mp3"
audio, sr = librosa.load(audio_path, sr=16000)

# %%
inputs = processor(audio, sampling_rate=16000, return_tensors="pt")

# %%
# inputs['input_features'].shape

# %%
# Generate translation (set task + target language)
forced_decoder_ids = processor.get_decoder_prompt_ids(
    language="fr",  # target language
    task="translate"
)

# %%
with torch.no_grad():
    predicted_ids = model.generate(
        inputs.input_features,
        forced_decoder_ids=forced_decoder_ids
    )

# %%
# Decode output
translation = processor.batch_decode(
    predicted_ids,
    skip_special_tokens=True
)

# %%
print("Translated text:", translation[0])
# Out:
# Translated text:  In the ancient land of Eldoria, where skies shimmered and forests whispered secrets to the wind, lived a dragon named Saphiros. Not the burn it all down kind, but he was gentle, wise, with eyes like old stars. Even the birds fell silent when he passed.
